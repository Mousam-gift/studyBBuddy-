# %% [markdown]
# <a href="https://colab.research.google.com/github/Mousam-gift/studyBBuddy-/blob/main/studyBBuddy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-adk

# %%
import os
from google import genai

os.environ["GOOGLE_API_KEY"] = "AIzaSyBX6_OG57MfIOz-4pAdNuXw2EIS3agX7Pk"
client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])

# %%
from google import genai
from google.genai import types

client = genai.Client()

SYSTEM_PROMPT = """
You are a helpful assistant that can help in three areas:
1) Education: explain concepts, make study plans, create quizzes.
2) Health information: ONLY general health info and lifestyle tips, no diagnosis or prescriptions. Always say you are not a doctor.
3) Sustainability: give practical eco-friendly habits and low-carbon tips.

Always:
- Mention which area(s) you are using (Education / Health info / Sustainability).
- Keep answers concise and clear.
"""

def smart_agent(message: str) -> str:
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=[
            types.Content(role="user", parts=[types.Part(text=SYSTEM_PROMPT)]),
            types.Content(role="user", parts=[types.Part(text=message)]),
        ],
    )
    return response.text

# %%
print(smart_agent("Help me make a weekly study plan that is healthy and sustainable."))
# Out:
# Here is a weekly study plan designed to be effective for your learning (Education), supportive of your well-being (Health info), and mindful of the planet (Sustainability).
#
# **Disclaimer:** I am not a doctor. This is general health information and lifestyle advice.
#
# ---
#
# **Weekly Study Plan: Healthy & Sustainable**
#
# **Areas used: Education, Health info, Sustainability**
#
# **Daily Flow (Monday - Friday)**
#
# *   **Morning (e.g., 8:00 AM - 12:00 PM):**
#     *   **Education:** 2-3 hours of focused study on your most challenging subject. Use active recall techniques.
#     *   **Health info:** Start with a nutritious breakfast and hydrate with water. Take a 10-minute stretch break every hour.
#     *   **Sustainability:** Utilize natural light as much as possible. Unplug device chargers when not in use.
# *   **Lunch & Movement Break (e.g., 12:00 PM - 1:00 PM):**
#     *   **Health info:** Eat a balanced meal. Go for a short walk outdoors to refresh your mind and get some physical activity.
#     *   **Sustainability:** Pack your lunch in reusable containers. Avoid food waste.
# *   **Afternoon (e.g., 1:00 PM - 5:00 PM):**
#     *   **Education:** 2-3 hours of study, focusing on a different subject or review. Incorporate spaced repetition.
#     *   **Health info:** Take a 15-minute screen break every 1-2 hours. Stand up, move around, or do eye exercises.
#     *   **Sustainability:** Take digital notes when possible to reduce paper. Turn off lights if leaving the room.
# *   **Evening Wind-Down (e.g., 5:00 PM onwards):**
#     *   **Education:** Briefly review the day's key concepts and plan for tomorrow's study.
#     *   **Health info:** Have a healthy dinner. Engage in relaxing activities (reading, mindfulness) before bed. Aim for 7-9 hours of quality sleep.
#     *   **Sustainability:** Power down and unplug all non-essential electronics before sleeping.
#
# **Weekend Balance (Saturday & Sunday)**
#
# *   **Saturday:**
#     *   **Education:** Review the week's material lightly for 1-2 hours. Plan specific goals for the next week.
#     *   **Health info:** Dedicate time to longer physical activity (e.g., hiking, cycling, sports). Prioritize social connections.
#     *   **Sustainability:** Use this day for eco-friendly errands (walk/bike if possible). Explore a plant-based meal.
# *   **Sunday:**
#     *   **Education:** Minimal study; perhaps a quick read-through of upcoming topics. Prepare materials for the week.
#     *   **Health info:** Focus on rest, relaxation, and nutritious meals to recharge.
#     *   **Sustainability:** Consider meal prepping with sustainable, locally sourced ingredients. Turn off all unused electronics in the house for efficiency.
#
# **General Tips:**
#
# *   **Hydration (Health info):** Keep a reusable water bottle handy and sip water throughout the day.
# *   **Flexibility (Education, Health info):** This is a template. Adjust study blocks and breaks to suit your personal energy levels and learning style.
# *   **Mindful Consumption (Sustainability):** If purchasing study supplies, opt for recycled or sustainably sourced options.

# %%
def classify_domain(message: str) -> str:
    m = message.lower()
    if any(w in m for w in ["study", "exam", "homework", "learn", "subject"]):
        return "education"
    if any(w in m for w in ["health", "diet", "exercise", "sleep", "doctor", "symptom"]):
        return "health"
    if any(w in m for w in ["climate", "carbon", "sustainable", "eco", "recycle", "footprint"]):
        return "sustainability"
    return "mixed"

def smart_routed_agent(message: str) -> str:
    domain = classify_domain(message)
    prefixed = f"[DOMAIN={domain}] {message}"
    return smart_agent(prefixed)

# %%
print(smart_routed_agent("Explain recursion and give me 3 quiz questions."))
print(smart_routed_agent("What habits improve heart health?"))
print(smart_routed_agent("How to reduce my carbon footprint as a student?"))
# Out:
# **Area: Education**
#
# Recursion is a programming technique where a function calls itself, directly or indirectly, to solve a problem. It works by breaking down a problem into smaller, similar subproblems until it reaches a "base case" – a simple condition that can be solved without further recursion.
#
# Key components:
# 1.  **Base Case:** The condition that stops the recursion. Without it, the function would call itself infinitely.
# 2.  **Recursive Step:** The part where the function calls itself with a modified input, moving closer to the base case.
#
# ---
#
# **Quiz Questions:**
#
# 1.  What is the essential component that prevents an infinite loop in a recursive function?
# 2.  In your own words, describe the main principle behind how recursion solves a problem.
# 3.  Which of the following problems is often a good candidate for a recursive solution?
#     a) Searching for an item in an unsorted list
#     b) Calculating the factorial of a number (e.g., 5! = 5 * 4 * 3 * 2 * 1)
#     c) Printing "Hello World" ten times using a simple loop
# [DOMAIN=Health information]
# I am not a doctor. Here are general lifestyle habits that can improve heart health:
#
# *   **Regular Physical Activity:** Aim for at least 30 minutes of moderate-intensity exercise most days of the week.
# *   **Balanced Diet:** Focus on fruits, vegetables, whole grains, lean proteins, and healthy fats. Limit processed foods, unhealthy saturated and trans fats, added sugars, and excessive sodium.
# *   **Maintain a Healthy Weight:** This reduces strain on your heart.
# *   **Manage Stress:** Practice relaxation techniques such as meditation, yoga, or spending time in nature.
# *   **Get Enough Sleep:** Aim for 7-9 hours of quality sleep per night.
# *   **Avoid Smoking/Vaping:** Quitting smoking is one of the best things you can do for your heart.
# *   **Limit Alcohol Intake:** If you drink alcohol, do so in moderation.
# [DOMAIN=Sustainability]
#
# Here are practical tips for students to reduce their carbon footprint:
#
# *   **Transportation:** Walk, bike, or use public transport instead of driving. Carpool when necessary.
# *   **Energy Use:** Unplug chargers and electronics when not in use, turn off lights, and use natural light as much as possible.
# *   **Food Choices:** Opt for more plant-based meals and reduce food waste. Bring your own reusable water bottle and coffee cup.
# *   **Consumption:** Buy secondhand items (clothing, books), borrow instead of buying new, and recycle properly.
# *   **Mindful Shopping:** Choose durable goods and avoid fast fashion.
